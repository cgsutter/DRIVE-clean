# %%
import pandas as pd

pd.set_option("display.max_columns", None)  # Show all columns
pd.set_option("display.width", None)        # Use full width of the console
pd.set_option("display.max_colwidth", None)  # Show full content in each column

import ast

# %%
# Check bins of confidence: 1) count how many observations had 5 vs 4 vs 3 etc models that aligned and 2) count distribution of probabilities (note that these probs are coming from the calibratred probabilties, so all good there)

dfs = []
paths = ["/home/csutter/DRIVE-clean/ensembling/data_preds/modelFinal_OT0.csv",
"/home/csutter/DRIVE-clean/ensembling/data_preds/modelFinal_OT1.csv",
"/home/csutter/DRIVE-clean/ensembling/data_preds/modelFinal_OT2.csv",
"/home/csutter/DRIVE-clean/ensembling/data_preds/modelFinal_OT3.csv",
"/home/csutter/DRIVE-clean/ensembling/data_preds/modelFinal_OT4.csv",
"/home/csutter/DRIVE-clean/ensembling/data_preds/modelFinal_OT5.csv"]

for p in paths:
    d = pd.read_csv(p)
    dfs.append(d)

df = pd.concat(dfs)

print(len(df))


# for i in df.columns:
#     print(i)



def consistency_row(row):
    cat = row["select"]
    dic = row["dict_catAsKeys_countAsValues"]
    dic = ast.literal_eval(dic)  # safely convert string → dict
    ct = dic[cat]
    return ct

df["consistency"] =df.apply(consistency_row, axis =1 )

display(df.head(4))
# Out:
# 21489
#    Unnamed: 0  index  Unnamed: 0.2  Unnamed: 0.1 m0_innerPhase outerPhase  \
# 0           0  16723         16723         16723   NAOuterTest  outerTest
# 1           1  16724         16724         16724   NAOuterTest  outerTest
# 2           2  16725         16725         16725   NAOuterTest  outerTest
# 3           3  16726         16726         16726   NAOuterTest  outerTest
#
#                                                           img_name  \
# 0  390_at_Lyell_Ave__Unknown__Skyline_6117_2022-01-25-00:00:10.jpg
# 1  390_at_Lyell_Ave__Unknown__Skyline_6117_2022-01-25-00:30:12.jpg
# 2  390_at_Lyell_Ave__Unknown__Skyline_6117_2022-01-25-00:45:12.jpg
# 3  390_at_Lyell_Ave__Unknown__Skyline_6117_2022-01-25-01:15:13.jpg
#
#                                                                                                                                              img_orig  \
# ...

# %%
df2 = df[["consistency","select_correct","img_orig"]].groupby(["consistency","select_correct"]).count().reset_index()

df2
# Out:
#    consistency  select_correct  img_orig
# 0            1           False        17
# 1            1            True        10
# 2            2           False       326
# 3            2            True       236
# 4            3           False       890
# 5            3            True       987
# 6            4           False      1015
# 7            4            True      1755
# 8            5           False      1720
# 9            5            True     14533
