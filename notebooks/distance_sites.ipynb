# %%
import pandas as pd
import numpy as np

# %%
nearest_nysm = pd.read_csv("/home/csutter/DRIVE/site_analysis/_reference/ny511sites_closest_mesonet.csv")
nearest_hrrr = pd.read_csv("/home/csutter/DRIVE/site_analysis/_reference/ny511sites_closest_hrrr_clean.csv")

print(np.mean(nearest_nysm["distance_km"]))
print(np.mean(nearest_hrrr["distance_km"]))
# Out:
# 42.80563209851806
# 3.25309988186714
